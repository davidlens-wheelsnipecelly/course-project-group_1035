# %%
import pandas as pd
project_files1 = pd.read_csv('data/raw/project files.csv')
project_files1
# Out:
# C:\Users\david\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,6,7,8,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015.0    1.0  1.0          4.0      AS           98.0      N407AS
# 1       2015.0    1.0  1.0          4.0      AA         2336.0      N3KUAA
# 2       2015.0    1.0  1.0          4.0      US          840.0      N171US
# 3       2015.0    1.0  1.0          4.0      AA          258.0      N3HYAA
# 4       2015.0    1.0  1.0          4.0      AS          135.0      N527AS
# ...        ...    ...  ...          ...     ...            ...         ...
# 619379  2015.0    NaN  NaN          NaN     NaN            NaN         NaN
# 619380  2015.0    NaN  NaN          NaN     NaN            NaN         NaN
# ...
